# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import lib_explo as lib


#print(filename_ytrain)
y_train = lib.get_ytrain()
X_train = lib.get_xtrain()
X_test = lib.get_xtest()

df = pd.concat([X_train, y_train], axis=1)

df.head()
# Out:
#                                          designation  \
# 0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4                               La Guerre Des Tuques
#
#                                          description   productid     imageid  \
# 0                                                NaN  3804725264  1263597046
# 1                                                NaN   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                NaN    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
#
#    img_shape  img_size  prdtypecode
# 0      14010     14010           10
# 1      14854     14854         2280
# 2       6898      6898           50
# ...

# %%
description = df['description']

description.dropna(inplace=True)

display(description)

import re
# as per recommendation from @freylis, compile once only
CLEANR = re.compile('<.*?>') 

from bs4 import BeautifulSoup
import lxml
#cleantext = BeautifulSoup(raw_html, "lxml").text

def cleanhtml(raw_html):  
  if len(raw_html) == 0:
    return ""
  cleantext = BeautifulSoup(raw_html)
  return cleantext.get_text()

df['description'] = df['description'].apply(cleanhtml)

#tmp = description.iloc[:100]
#tmp2 = tmp.apply(cleanhtml)
#display(tmp2)

print(df.iloc[73552]['description'])
# Out:
# 2        PILOT STYLE Touch Pen de marque Speedlink est ...
# 4        Luc a des id&eacute;es de grandeur. Il veut or...
# 7        CONQUERANT CLASSIQUE Cahier 240 x 320 mm seyès...
# 9        Tente pliante V3S5 Pro PVC 500 gr/m² - 3 x 4m5...
# 10       The timeless DSW seat can now be paired with m...
#                                ...
# 84908    Nom de la marque:oobest<br />Ampoules incluses...
# 84909    espa espa - kit complet de nage à contre coura...
# 84910    le t - shirt rayé mode chiens  petits chiots v...
# 84912    <b>Description complète :</b><br />Kit piscine...
# 84914    <p>Cette table basse a un design unique et con...
# Name: description, Length: 55116, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 19
#      16   cleantext = BeautifulSoup(raw_html)
#      17   return cleantext.get_text()
# ...
